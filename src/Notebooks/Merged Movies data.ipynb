# %%
#importing libraries
from sklearn import datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
#reading training data set
mm = pd.read_csv('Merged_Movies_data.csv')
print("First few rows of the training dataset:")
mm.head()
# Out:
# First few rows of the training dataset:
#    movieId  imdbId   tmdbId                        title original_language  \
# 0        1  114709    862.0                    Toy Story                en
# 1        2  113497   8844.0                      Jumanji                en
# 2        3  113228  15602.0             Grumpier Old Men                en
# 3        4  114885  31357.0            Waiting to Exhale                en
# 4        5  113041  11862.0  Father of the Bride Part II                en
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                                             overview  popularity  adult  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943  False
# ...

# %%
mm.shape
# Out:
# (47291, 30)

# %%
mm_image = mm[~(mm['poster_working_url'] == 'Image not found')]
mm_image
# Out:
#        movieId   imdbId    tmdbId                             title  \
# 1            2   113497    8844.0                           Jumanji
# 18          19   112281    9273.0    Ace Ventura: When Nature Calls
# 19          20   113845   11517.0                       Money Train
# 31          32   114746      63.0                    Twelve Monkeys
# 33          34   112431    9598.0                              Babe
# ...        ...      ...       ...                               ...
# 46894   176235   457437   14885.0  Pooh's Heffalump Halloween Movie
# 46898   176249  5690142  404604.0                               Mom
# 46905   176267   102797   30840.0                        Robin Hood
# 46907   176271  2028550  111109.0               Century of Birthing
# 46910   176279  6980792  461257.0                          Queerama
#
#       original_language                                    tagline  \
# 1                    en  Roll the dice and unleash the excitement!
# ...

# %%
mm_image.isnull().sum()
# Out:
# movieId                     0
# imdbId                      0
# tmdbId                      0
# title                       0
# original_language           3
# tagline                  3569
# overview                  120
# popularity                  0
# adult                       0
# poster_path                 0
# budget                      0
# genres                      0
# homepage                 5169
# belongs_to_collection    5608
# production_companies        0
# production_countries        0
# release_date               12
# revenue                     0
# runtime                    31
# spoken_languages            0
# status                      6
# video                       0
# vote_average                0
# vote_count                  0
# keywords                    1
# cast                        1
# crew                        1
# original_title              0
# imdb_id                     4
# poster_working_url          0
# dtype: int64

# %%
movies_data = mm_image.drop(columns = ['belongs_to_collection', 'homepage', 'tagline', 'imdb_id', 'poster_path', 'original_title'] , axis = 1 )

# %%
movies_data.isnull().sum()
# Out:
# movieId                   0
# imdbId                    0
# tmdbId                    0
# title                     0
# original_language         3
# overview                120
# popularity                0
# adult                     0
# budget                    0
# genres                    0
# production_companies      0
# production_countries      0
# release_date             12
# revenue                   0
# runtime                  31
# spoken_languages          0
# status                    6
# video                     0
# vote_average              0
# vote_count                0
# keywords                  1
# cast                      1
# crew                      1
# poster_working_url        0
# dtype: int64

# %%
movies_data.dropna(inplace = True)

# %%
movies_data
# Out:
#        movieId   imdbId    tmdbId                             title  \
# 1            2   113497    8844.0                           Jumanji
# 18          19   112281    9273.0    Ace Ventura: When Nature Calls
# 19          20   113845   11517.0                       Money Train
# 31          32   114746      63.0                    Twelve Monkeys
# 33          34   112431    9598.0                              Babe
# ...        ...      ...       ...                               ...
# 46894   176235   457437   14885.0  Pooh's Heffalump Halloween Movie
# 46898   176249  5690142  404604.0                               Mom
# 46905   176267   102797   30840.0                        Robin Hood
# 46907   176271  2028550  111109.0               Century of Birthing
# 46910   176279  6980792  461257.0                          Queerama
#
#       original_language                                           overview  \
# ...

# %%
movies_data.shape
# Out:
# (6139, 24)

# %%
movies_data.isnull().sum()
# Out:
# movieId                 0
# imdbId                  0
# tmdbId                  0
# title                   0
# original_language       0
# overview                0
# popularity              0
# adult                   0
# budget                  0
# genres                  0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# video                   0
# vote_average            0
# vote_count              0
# keywords                0
# cast                    0
# crew                    0
# poster_working_url      0
# dtype: int64

# %% [markdown]
# #### Final movies_data with no missing values shape(6139*26)

# %%
movies_data['popularity'].value_counts()
# Out:
# 3.008299    8
# 0.000844    8
# 3.185256    8
# 0.000220    6
# 0.000308    6
#            ..
# 0.619084    1
# 9.482806    1
# 0.661981    1
# 0.584232    1
# 0.163015    1
# Name: popularity, Length: 5951, dtype: int64

# %%
movies_data['adult'].value_counts()
# Out:
# False    6135
# True        4
# Name: adult, dtype: int64

# %%
movies_data['budget'].value_counts()
# Out:
# 0.0            4876
# 20000000.0       34
# 5000000.0        33
# 4000000.0        32
# 10000000.0       32
#                ...
# 2160000.0         1
# 5800000.0         1
# 60795000.0        1
# 258000000.0       1
# 3417000.0         1
# Name: budget, Length: 370, dtype: int64

# %%
movies_data['genres'].value_counts()
# Out:
# [{'id': 18, 'name': 'Drama'}]                                                                                                 692
# [{'id': 35, 'name': 'Comedy'}]                                                                                                463
# [{'id': 99, 'name': 'Documentary'}]                                                                                           302
# []                                                                                                                            231
# [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]                                                               176
#                                                                                                                              ...
# [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'id': 36, 'name': 'History'}]                                  1
# ...

# %%
movies_data['production_companies'].value_counts()
# Out:
# []                                                                                                                                                                                                                                                                                  1372
# [{'name': 'Metro-Goldwyn-Mayer (MGM)', 'id': 8411}]                                                                                                                                                                                                                                  120
# [{'name': 'Twentieth Century Fox Film Corporation', 'id': 306}]                                                                                                                                                                                                                       78
# ...

# %%
movies_data['production_countries'].value_counts()
# Out:
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]                                                                                                                                     2349
# []                                                                                                                                                                                              633
# [{'iso_3166_1': 'JP', 'name': 'Japan'}]                                                                                                                                                         277
# [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]                                                                                                                                                276
# [{'iso_3166_1': 'FR', 'name': 'France'}]                                                                                                                                                        251
# ...

# %%
movies_data['release_date'].value_counts()
# Out:
# 2005-09-03    17
# 2008-01-01    14
# 1981-01-01    13
# 2004-01-01    13
# 1989-01-01    13
#               ..
# 2008-03-29     1
# 1960-12-01     1
# 1935-12-25     1
# 2003-04-10     1
# 2011-11-17     1
# Name: release_date, Length: 4564, dtype: int64

# %%
movies_data['revenue'].value_counts()
# Out:
# 0.0            5081
# 2500000.0         4
# 11000000.0        3
# 32000000.0        3
# 6000000.0         3
#                ...
# 940335536.0       1
# 51142659.0        1
# 259175788.0       1
# 6746000.0         1
# 184770205.0       1
# Name: revenue, Length: 1021, dtype: int64

# %%
movies_data['runtime'].value_counts()
# Out:
# 90.0     316
# 95.0     201
# 100.0    200
# 93.0     159
# 92.0     139
#         ...
# 252.0      1
# 925.0      1
# 237.0      1
# 207.0      1
# 34.0       1
# Name: runtime, Length: 239, dtype: int64

# %%
movies_data['spoken_languages'].value_counts()
# Out:
# [{'iso_639_1': 'en', 'name': 'English'}]                                                                                                                                                                2902
# []                                                                                                                                                                                                       312
# [{'iso_639_1': 'fr', 'name': 'Français'}]                                                                                                                                                                280
# [{'iso_639_1': 'ja', 'name': '日本語'}]                                                                                                                                                                     258
# ...

# %%
movies_data['status'].value_counts()
# Out:
# Released           6064
# Rumored              37
# Post Production      29
# In Production         5
# Planned               4
# Name: status, dtype: int64

# %%
movies_data['video'].value_counts()
# Out:
# False    6130
# True        9
# Name: video, dtype: int64

# %%
movies_data['vote_average'].value_counts()
# Out:
# 6.0    318
# 7.0    272
# 0.0    258
# 6.5    249
# 5.0    230
#       ...
# 9.8      1
# 9.1      1
# 8.9      1
# 1.8      1
# 9.4      1
# Name: vote_average, Length: 84, dtype: int64

# %%
movies_data['vote_count'].value_counts()
# Out:
# 3.0       392
# 2.0       368
# 4.0       342
# 1.0       337
# 5.0       287
#          ...
# 8226.0      1
# 1946.0      1
# 1007.0      1
# 1410.0      1
# 324.0       1
# Name: vote_count, Length: 740, dtype: int64

# %%
movies_data = movies_data.drop(columns = ['adult', 'video', 'status'] , axis = 1 )

# %%
movies_data
# Out:
#        movieId   imdbId    tmdbId                             title  \
# 1            2   113497    8844.0                           Jumanji
# 18          19   112281    9273.0    Ace Ventura: When Nature Calls
# 19          20   113845   11517.0                       Money Train
# 31          32   114746      63.0                    Twelve Monkeys
# 33          34   112431    9598.0                              Babe
# ...        ...      ...       ...                               ...
# 46894   176235   457437   14885.0  Pooh's Heffalump Halloween Movie
# 46898   176249  5690142  404604.0                               Mom
# 46905   176267   102797   30840.0                        Robin Hood
# 46907   176271  2028550  111109.0               Century of Birthing
# 46910   176279  6980792  461257.0                          Queerama
#
#       original_language                                           overview  \
# ...

# %%
movies_data.shape
# Out:
# (6139, 21)

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6139 entries, 1 to 46910
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movieId               6139 non-null   int64
#  1   imdbId                6139 non-null   int64
#  2   tmdbId                6139 non-null   float64
#  3   title                 6139 non-null   object
#  4   original_language     6139 non-null   object
#  5   overview              6139 non-null   object
#  6   popularity            6139 non-null   float64
#  7   budget                6139 non-null   float64
#  8   genres                6139 non-null   object
#  9   production_companies  6139 non-null   object
#  10  production_countries  6139 non-null   object
#  11  release_date          6139 non-null   object
#  12  revenue               6139 non-null   float64
#  13  runtime               6139 non-null   float64
#  14  spoken_languages      6139 non-null   object
# ...

# %%
movies_data.replace('[]', pd.NA, inplace=True)

# Drop rows with NaN values in any column
movies_data.dropna(inplace=True)

# %%
movies_data
# Out:
#        movieId   imdbId    tmdbId                             title  \
# 1            2   113497    8844.0                           Jumanji
# 18          19   112281    9273.0    Ace Ventura: When Nature Calls
# 19          20   113845   11517.0                       Money Train
# 31          32   114746      63.0                    Twelve Monkeys
# 33          34   112431    9598.0                              Babe
# ...        ...      ...       ...                               ...
# 46878   176201   232750    5589.0           Šíleně smutná princezna
# 46884   176215    36975   84710.0                      Jungle Woman
# 46894   176235   457437   14885.0  Pooh's Heffalump Halloween Movie
# 46898   176249  5690142  404604.0                               Mom
# 46907   176271  2028550  111109.0               Century of Birthing
#
#       original_language                                           overview  \
# ...

# %% [markdown]
# **Final movies data with 3660 rows and 21 columns**
#
# 1. Removed columns - ['adult', 'video', 'status'] in Movies_data(3660) and ['belongs_to_collection', 'homepage', 'tagline', 'imdb_id', 'poster_path', 'original_title'] in Movies_data(6139).
#
# 2. In Movies_data(6139), all missing values are removed except the empty lists present for 'spoken_languages', 'production_countries', 'production_companies', 'genres', 'cast', 'crew' and 'keywords'.
#
# 3. In Movies_data(3660) all mising values are removed including empty lists.
#
# 4. Dim(Movies_data(3660)) = 3660x21
#
# 5. Dim(Movies_data(6139)) = 6139x24

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3660 entries, 1 to 46907
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movieId               3660 non-null   int64
#  1   imdbId                3660 non-null   int64
#  2   tmdbId                3660 non-null   float64
#  3   title                 3660 non-null   object
#  4   original_language     3660 non-null   object
#  5   overview              3660 non-null   object
#  6   popularity            3660 non-null   float64
#  7   budget                3660 non-null   float64
#  8   genres                3660 non-null   object
#  9   production_companies  3660 non-null   object
#  10  production_countries  3660 non-null   object
#  11  release_date          3660 non-null   object
#  12  revenue               3660 non-null   float64
#  13  runtime               3660 non-null   float64
#  14  spoken_languages      3660 non-null   object
# ...
